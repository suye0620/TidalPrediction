# %% [markdown]
# ,,degrees_east,degrees_north,UTC,millibars,degrees true,knots,knots,meters,seconds,degrees_true,meters,degrees_C,degrees_C,degrees_C,dimensionless,percent,degrees,degrees_true,seconds,

# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_theme(style="whitegrid")

# 加载数据
df_Ballycotton = pd.read_csv("./newdata",encoding = "utf-8",index_col=['time'],parse_dates = ["time"],usecols = ['time','SeaTemperature'])
# 转化为时间序列
# df_Ballycotton['time'] = pd.to_datetime(df_Ballycotton['time'])
# 设置时间索引
# df_Ballycotton = df_Ballycotton.set_index("time")

# %%
# 画图
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(1,1,1)
sns.set_theme(style="whitegrid")
# dataPlot = df_Ballycotton.loc[:,"Water_Level_LAT"]
sns.lineplot(data=df_Ballycotton['2018-12'], palette="tab10", linewidth=2.5,ax=ax)
# 将x轴斜过来显示更好看
fig.autofmt_xdate()
# Out:
# C:\Users\Administrator\AppData\Local\Temp/ipykernel_17944/4187264462.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   sns.lineplot(data=df_Ballycotton['2018-12'], palette="tab10", linewidth=2.5,ax=ax)

# %%
# 数据缺失情况
sum(df_Ballycotton.loc[:,'SeaTemperature'].isna())
# Out:
# 10777
